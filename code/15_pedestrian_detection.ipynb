# %%
import cv2 as cv
import matplotlib.pyplot as plt
from skimage import io

# %% [markdown]
# ### Dalal-Triggs Pedestrian Detector

# %%
img = io.imread('data/csm3.jpg')

hog = cv.HOGDescriptor()
hog.setSVMDetector(cv.HOGDescriptor_getDefaultPeopleDetector())
  
(regions, _) = hog.detectMultiScale(img,
    hitThreshold=0,
    winStride=(8,8),
    padding=(0,0),
    scale=1.05,
    groupThreshold=2,
    useMeanshiftGrouping=False)
  
# Drawing the regions in the Image
for (x, y, w, h) in regions:
    cv.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), thickness=3)

plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.title("Pedestrians Detected")
# Out:
# Text(0.5, 1.0, 'Pedestrians Detected')
